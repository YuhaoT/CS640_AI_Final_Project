# %%
import pandas as pd
import json
import shutil

# %%
labeled_users = './data/labeled_users.csv'
user_demo_profiles_path = './data/User demo profiles.json'

df_users = pd.read_csv(labeled_users)
df_profiles = pd.read_json(user_demo_profiles_path, orient='values')

# %%
df_profiles
# Out:
#               id                                 name      screen_name  \
# 0          12488                           Chad Boyce         djsnipa1
# 1         719703                             Tomato 😷           Tomato
# 2         722153                                blank            blank
# 3         749003  A ring made from a spoon --- E83.31            IYQbd
# 4     1896301728                              عبدالله           755531
# ...          ...                                  ...              ...
# 3604  4895390642                    Dalton's Eyeliner  FlyAwayEyeliner
# 3605  4895831833                         Jamie Loftus    cowboyjamie77
# 3606  4921995243                                saved         memelady
# 3607  4924158634                  Winter da CoffeeCat     WinterStar21
# 3608  4928657861                 magical fluff nugget      ohitspotato
#
#                                             description lang  \
# 0     Multimedia Developer, Graphic Designer, DJ, an...   NA
# 1                                            🇭🇰Rise Up!   NA
# 2         Someone who thinks too much, acts too little.   NA
# 3     Has the kind of luck that turns a professional...   NA
# 4                                                         NA
# ...                                                 ...  ...
# 3604  I'm Dalton's eyeliner, who are you? Are you Da...   NA
# 3605  41 year old male. interests include learning, ...   NA
# 3606                                                      NA
# 3607  Big fan of cats, coffee, horror stuff and anim...   NA
# 3608  ADHD and all that fun stuff. Future counselor....   NA
#
#                      img_path
# 0     profile pics/60147.jpeg
# 1     profile pics/60148.jpeg
# 2     profile pics/60149.jpeg
# 3     profile pics/60150.jpeg
# 4     profile pics/60151.jpeg
# ...                       ...
# 3604  profile pics/64267.jpeg
# 3605  profile pics/64268.jpeg
# 3606  profile pics/64269.jpeg
# 3607  profile pics/64270.jpeg
# 3608  profile pics/64271.jpeg
#
# [3609 rows x 6 columns]

# %%
df_tmp = df_profiles.drop(['name','screen_name','description','lang'],axis = 1)

for index, row in df_tmp.iterrows():
    id = row[0]
    path = row[1]
    source_path = './data/img' + path[12:]
    dest_path = './data/' + path

    try:
        shutil.copyfile(source_path,dest_path)
    except(FileNotFoundError):
        print(id,path)
# Out:
# 13981312 profile pics/60239.jpeg
# 15810975 profile pics/60316.jpeg
# 16239701 profile pics/60338.jpeg
# 17481031 profile pics/60390.jpeg
# 18693062 profile pics/60442.jpeg
# 18701876 profile pics/60443.jpeg
# 18888658 profile pics/60452.jpeg
# 23223898 profile pics/60561.jpeg
# 23772938 profile pics/60590.jpeg
# 27956258 profile pics/60698.jpeg
# 30098713 profile pics/60756.jpeg
# 36509410 profile pics/60878.jpeg
# 37071176 profile pics/60887.jpeg
# 44191726 profile pics/60985.jpeg
# 61668553 profile pics/61127.jpeg
# 62990956 profile pics/61136.jpeg
