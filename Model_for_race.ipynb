# %%
from facenet_pytorch import InceptionResnetV1, training, fixed_image_standardization
from torch.utils.tensorboard import SummaryWriter
import torch
import torchvision
import pandas as pd
import numpy as np
import os
from PIL import Image

# %%
batch_size = 32
epochs = 16
workers = 0 if os.name == 'nt' else 8
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print('Running on device: {}'.format(device))
# Out:
# Running on device: cuda:0

# %% [markdown]
# # Load Data

# %%
data = pd.read_pickle('./data.pkl')
data['race'] = np.where(
   (data['race'] != 4) & (data['race'] != 1) , 0.0, data['race']
   )
data['race'] = np.where(
    data['race'] == 4, 2.0, data['race']
)
print(data['race'].value_counts())
data.head()
# Out:
# 2.0    2726
# 0.0     443
# 1.0     318
# Name: race, dtype: int64
#          id  race                 img_path               absolute_img_path  \
# 0   12488.0   2.0  profile pics/60147.jpeg  ./data/profile pics/60147.jpeg
# 1  719703.0   2.0  profile pics/60148.jpeg  ./data/profile pics/60148.jpeg
# 2  722153.0   0.0  profile pics/60149.jpeg  ./data/profile pics/60149.jpeg
# 3  749003.0   0.0  profile pics/60150.jpeg  ./data/profile pics/60150.jpeg
# 5  811618.0   0.0  profile pics/60152.jpeg  ./data/profile pics/60152.jpeg
#
#                 cropped_path
# 0  ./data/cropped/60147.jpeg
# 1  ./data/cropped/60148.jpeg
# 2  ./data/cropped/60149.jpeg
# 3  ./data/cropped/60150.jpeg
# 5  ./data/cropped/60152.jpeg

# %%
def load_images(input):
    if os.path.exists(input):
        tmp = Image.open(input)
        test = tmp.getbands()
        keep = tmp.copy()
        return keep
    else: return pd.NA

# %%
data['face'] = data['cropped_path'].apply(load_images)
data = data.dropna()
print(data.shape)
data.head()
# Out:
# (2477, 6)
#            id  race                 img_path               absolute_img_path  \
# 5    811618.0   0.0  profile pics/60152.jpeg  ./data/profile pics/60152.jpeg
# 7    865071.0   2.0  profile pics/60154.jpeg  ./data/profile pics/60154.jpeg
# 8    988211.0   2.0  profile pics/60155.jpeg  ./data/profile pics/60155.jpeg
# 9   1025311.0   2.0  profile pics/60156.jpeg  ./data/profile pics/60156.jpeg
# 10  1143891.0   0.0  profile pics/60157.jpeg  ./data/profile pics/60157.jpeg
#
#                  cropped_path  \
# 5   ./data/cropped/60152.jpeg
# 7   ./data/cropped/60154.jpeg
# 8   ./data/cropped/60155.jpeg
# 9   ./data/cropped/60156.jpeg
# 10  ./data/cropped/60157.jpeg
#
#                                                  face
# 5   <PIL.Image.Image image mode=RGB size=160x160 a...
# 7   <PIL.Image.Image image mode=RGB size=160x160 a...
# 8   <PIL.Image.Image image mode=RGB size=160x160 a...
# 9   <PIL.Image.Image image mode=RGB size=160x160 a...
# 10  <PIL.Image.Image image mode=RGB size=160x160 a...

# %% [markdown]
# # Build dataset and dataloader

# %%
tmp = data[['face','race']].reset_index(drop=True)
x = tmp['face'].tolist()
y = tmp['race'].tolist()

# %%
class Face_Race_Dataset(torch.utils.data.Dataset):
    def __init__(self, x,y):
        self.x = x
        self.y = y
        self.transform = torchvision.transforms.Compose(
                            [
                            np.float32,
                            torchvision.transforms.ToTensor(),
                            fixed_image_standardization])

    def __len__(self):
        return len(self.x)

    def __getitem__(self, index):
        return self.transform(self.x[index]),torch.tensor(self.y[index],dtype=torch.long)

# %%
dataset = Face_Race_Dataset(x,y)

# %%
#all_data = torch.utils.data.DataLoader(dataset,batch_size=10,num_workers=workers,shuffle=True)

# %%
train_size = int(0.9 * len(dataset))
valid_size = (len(dataset) - train_size)
train_set,valid_size = torch.utils.data.random_split(dataset,[train_size,valid_size])

# train_size = int(0.8 * len(dataset))
# valid_size = (len(dataset) - train_size)
# train_set,valid_size = torch.utils.data.random_split(dataset,[train_size,valid_size])

# valid_size = int(valid_size / 2)
# test_size = valid_size
# valid_set,test_set = torch.utils.data.random_split(valid_size,[valid_size,test_size])

# %%
train_loader = torch.utils.data.DataLoader(train_set,batch_size=32,num_workers=workers,shuffle=True)
test_loader = torch.utils.data.DataLoader(test_set,batch_size=32,num_workers=workers,shuffle=True)
valid_loader = torch.utils.data.DataLoader(valid_set,batch_size=32,num_workers=workers,shuffle=True)
test = next(iter(valid_loader))
# Out:
# C:\Users\zhouy\AppData\Local\Temp/ipykernel_20240/2642461197.py:15: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   return self.transform(self.x[index]),torch.tensor(self.y[index],dtype=torch.long)
# [tensor([[[[-0.2773, -0.2773, -0.2773,  ...,  0.2930,  0.2930,  0.2930],
#            [-0.2773, -0.2773, -0.2773,  ...,  0.3086,  0.3086,  0.3086],
#            [-0.2773, -0.2773, -0.2773,  ...,  0.2930,  0.3008,  0.3008],
#            ...,
#            [ 0.1914,  0.1836,  0.1914,  ...,  0.0977,  0.0977,  0.0977],
#            [ 0.1914,  0.1914,  0.1914,  ...,  0.0898,  0.0977,  0.0977],
#            [ 0.1914,  0.1914,  0.1992,  ...,  0.0977,  0.0977,  0.0977]],
#
#           [[-0.2930, -0.2930, -0.2930,  ...,  0.3086,  0.3086,  0.3086],
#            [-0.2930, -0.2930, -0.2930,  ...,  0.3242,  0.3242,  0.3242],
#            [-0.2930, -0.2930, -0.2930,  ...,  0.2930,  0.3008,  0.3008],
#            ...,
#            [-0.0273, -0.0352, -0.0430,  ...,  0.0820,  0.0820,  0.0820],
#            [-0.0273, -0.0273, -0.0430,  ...,  0.0820,  0.0898,  0.0898],
#            [-0.0273, -0.0273, -0.0352,  ...,  0.0898,  0.0898,  0.0898]],
#
#           [[-0.1211, -0.1211, -0.1211,  ...,  0.4023,  0.4023,  0.4023],
#            [-0.1211, -0.1211, -0.1211,  ...,  0.4180,  0.4180,  0.4180],
#            [-0.1211, -0.1211, -0.1211,  ...,  0.3711,  0.3789,  0.3789],
#            ...,
#            [-0.1133, -0.1211, -0.1211,  ...,  0.1055,  0.1055,  0.1055],
#            [-0.1133, -0.1133, -0.1211,  ...,  0.1211,  0.1289,  0.1289],
#            [-0.1133, -0.1133, -0.1133,  ...,  0.1289,  0.1289,  0.1289]]],
#
#
#          [[[-0.4023, -0.3945, -0.3711,  ...,  0.9336,  0.9492,  0.9492],
#            [-0.4023, -0.3867, -0.3789,  ...,  0.9336,  0.9492,  0.9492],
#            [-0.3789, -0.3789, -0.3711,  ...,  0.9492,  0.9492,  0.9492],
#            ...,
#            [-0.7148, -0.7148, -0.7148,  ...,  0.9258,  0.9180,  0.9180],
#            [-0.7148, -0.7148, -0.7148,  ...,  0.9180,  0.9102,  0.9102],
#            [-0.7148, -0.7148, -0.7148,  ...,  0.9180,  0.9102,  0.9023]],
#
#           [[-0.6055, -0.5977, -0.6055,  ...,  0.9961,  0.9961,  0.9961],
#            [-0.6055, -0.6055, -0.6133,  ...,  0.9961,  0.9961,  0.9961],
#            [-0.5977, -0.5977, -0.6055,  ...,  0.9961,  0.9961,  0.9961],
#            ...,
#            [-0.8320, -0.8320, -0.8320,  ...,  0.9492,  0.9414,  0.9414],
#            [-0.8320, -0.8320, -0.8320,  ...,  0.9414,  0.9336,  0.9336],
#            [-0.8320, -0.8320, -0.8320,  ...,  0.9414,  0.9336,  0.9258]],
#
#           [[-0.6133, -0.6055, -0.6055,  ...,  0.9961,  0.9961,  0.9961],
#            [-0.6133, -0.6133, -0.6133,  ...,  0.9961,  0.9961,  0.9961],
#            [-0.6055, -0.6055, -0.6055,  ...,  0.9805,  0.9961,  0.9961],
#            ...,
#            [-0.7773, -0.7773, -0.7773,  ...,  0.9883,  0.9805,  0.9805],
#            [-0.7773, -0.7773, -0.7773,  ...,  0.9805,  0.9727,  0.9727],
#            [-0.7773, -0.7773, -0.7773,  ...,  0.9805,  0.9727,  0.9648]]],
#
#
#          [[[-0.4570, -0.4805, -0.5273,  ..., -0.6133, -0.6055, -0.5977],
#            [-0.4805, -0.5039, -0.5430,  ..., -0.6055, -0.5977, -0.5898],
#            [-0.5430, -0.5664, -0.5898,  ..., -0.5977, -0.5977, -0.5898],
#            ...,
#            [ 0.6133,  0.6211,  0.6289,  ...,  0.3789,  0.3633,  0.3633],
#            [ 0.5977,  0.5977,  0.6055,  ...,  0.3945,  0.3789,  0.3867],
#            [ 0.5977,  0.5977,  0.6055,  ...,  0.4023,  0.3945,  0.4023]],
#
#           [[-0.5586, -0.5820, -0.6289,  ..., -0.7383, -0.7305, -0.7227],
#            [-0.5898, -0.6055, -0.6523,  ..., -0.7305, -0.7227, -0.7148],
#            [-0.6289, -0.6523, -0.6758,  ..., -0.7227, -0.7227, -0.7148],
#            ...,
#            [ 0.5898,  0.5977,  0.5977,  ..., -0.0977, -0.0898, -0.0898],
#            [ 0.5898,  0.5898,  0.5820,  ..., -0.0820, -0.0742, -0.0664],
#            [ 0.5898,  0.5898,  0.5820,  ..., -0.0742, -0.0586, -0.0508]],
#
#           [[-0.6055, -0.6289, -0.6758,  ..., -0.8398, -0.8320, -0.8242],
#            [-0.6133, -0.6523, -0.6758,  ..., -0.8320, -0.8242, -0.8164],
#            [-0.6445, -0.6836, -0.6914,  ..., -0.8242, -0.8242, -0.8164],
#            ...,
#            [ 0.2383,  0.2461,  0.2461,  ..., -0.2617, -0.2773, -0.2773],
#            [ 0.2305,  0.2305,  0.2305,  ..., -0.2461, -0.2461, -0.2383],
#            [ 0.2305,  0.2305,  0.2305,  ..., -0.2383, -0.2305, -0.2227]]],
#
#
#          ...,
#
#
#          [[[-0.8945, -0.8711, -0.8320,  ..., -0.2617, -0.2539, -0.2539],
#            [-0.8633, -0.8555, -0.8320,  ..., -0.3086, -0.3008, -0.2930],
#            [-0.8086, -0.8086, -0.7930,  ..., -0.3477, -0.3320, -0.3164],
#            ...,
#            [ 0.3555,  0.3711,  0.3945,  ...,  0.0742,  0.1211,  0.1445],
#            [ 0.3242,  0.3398,  0.3633,  ...,  0.0664,  0.1055,  0.1289],
#            [ 0.3086,  0.3320,  0.3555,  ...,  0.0508,  0.0898,  0.1055]],
#
#           [[-0.9414, -0.9180, -0.9023,  ..., -0.4102, -0.4023, -0.4023],
#            [-0.9102, -0.9023, -0.9023,  ..., -0.4570, -0.4492, -0.4414],
#            [-0.8398, -0.8398, -0.8398,  ..., -0.4961, -0.4805, -0.4648],
#            ...,
#            [-0.0430, -0.0273, -0.0039,  ..., -0.0664, -0.0195,  0.0039],
#            [-0.0508, -0.0352, -0.0117,  ..., -0.0820, -0.0430, -0.0195],
#            [-0.0664, -0.0430, -0.0195,  ..., -0.0977, -0.0586, -0.0430]],
#
#           [[-0.9102, -0.8867, -0.8789,  ..., -0.5273, -0.5195, -0.5195],
#            [-0.8789, -0.8867, -0.8789,  ..., -0.5742, -0.5664, -0.5586],
#            [-0.8320, -0.8320, -0.8242,  ..., -0.6133, -0.5977, -0.5820],
#            ...,
#            [-0.3789, -0.3633, -0.3398,  ..., -0.1602, -0.1289, -0.1055],
#            [-0.4102, -0.3945, -0.3711,  ..., -0.1914, -0.1523, -0.1289],
#            [-0.4258, -0.4023, -0.3789,  ..., -0.2070, -0.1680, -0.1523]]],
#
#
#          [[[ 0.2383,  0.2305,  0.2227,  ..., -0.7461, -0.7539, -0.7617],
#            [ 0.2227,  0.2148,  0.2070,  ..., -0.7148, -0.7227, -0.7305],
#            [ 0.2070,  0.1992,  0.1836,  ..., -0.6523, -0.6680, -0.6758],
#            ...,
#            [-0.3867, -0.3945, -0.3320,  ...,  0.3242,  0.3164,  0.3242],
#            [-0.3633, -0.3945, -0.3711,  ...,  0.3477,  0.3398,  0.3398],
#            [-0.3477, -0.4023, -0.4180,  ...,  0.3711,  0.3555,  0.3477]],
#
#           [[ 0.2227,  0.2148,  0.2070,  ..., -0.7617, -0.7695, -0.7773],
#            [ 0.2070,  0.1992,  0.1914,  ..., -0.7305, -0.7383, -0.7461],
#            [ 0.1914,  0.1836,  0.1680,  ..., -0.6680, -0.6836, -0.6914],
#            ...,
#            [-0.4023, -0.4102, -0.3477,  ...,  0.3086,  0.3008,  0.3086],
#            [-0.3789, -0.4102, -0.3867,  ...,  0.3320,  0.3242,  0.3242],
#            [-0.3633, -0.4180, -0.4336,  ...,  0.3555,  0.3398,  0.3320]],
#
#           [[ 0.2461,  0.2383,  0.2305,  ..., -0.7383, -0.7461, -0.7539],
#            [ 0.2305,  0.2227,  0.2148,  ..., -0.7070, -0.7148, -0.7227],
#            [ 0.2148,  0.2070,  0.1914,  ..., -0.6445, -0.6602, -0.6680],
#            ...,
#            [-0.3789, -0.3867, -0.3242,  ...,  0.3320,  0.3242,  0.3320],
#            [-0.3555, -0.3867, -0.3633,  ...,  0.3555,  0.3477,  0.3477],
#            [-0.3398, -0.3945, -0.4102,  ...,  0.3789,  0.3633,  0.3555]]],
#
#
#          [[[-0.7070, -0.7070, -0.7070,  ..., -0.5898, -0.5820, -0.5820],
#            [-0.7070, -0.7070, -0.7070,  ..., -0.5898, -0.5898, -0.5820],
#            [-0.7070, -0.7070, -0.7070,  ..., -0.5977, -0.5898, -0.5898],
#            ...,
#            [-0.5430, -0.5430, -0.5430,  ..., -0.6367, -0.6445, -0.6445],
#            [-0.5352, -0.5352, -0.5352,  ..., -0.6289, -0.6367, -0.6367],
#            [-0.5352, -0.5352, -0.5352,  ..., -0.6289, -0.6289, -0.6367]],
#
#           [[-0.8398, -0.8398, -0.8398,  ..., -0.6836, -0.6758, -0.6758],
#            [-0.8398, -0.8398, -0.8398,  ..., -0.6836, -0.6836, -0.6758],
#            [-0.8477, -0.8477, -0.8477,  ..., -0.6914, -0.6836, -0.6836],
#            ...,
#            [-0.7305, -0.7305, -0.7305,  ..., -0.8008, -0.8086, -0.8086],
#            [-0.7227, -0.7227, -0.7227,  ..., -0.7930, -0.8008, -0.8008],
#            [-0.7227, -0.7227, -0.7227,  ..., -0.7930, -0.7930, -0.8008]],
#
#           [[-0.9180, -0.9180, -0.9180,  ..., -0.7930, -0.7852, -0.7852],
#            [-0.9180, -0.9180, -0.9180,  ..., -0.7930, -0.7930, -0.7852],
#            [-0.9258, -0.9258, -0.9414,  ..., -0.8008, -0.7930, -0.7930],
#            ...,
#            [-0.8242, -0.8242, -0.8242,  ..., -0.9336, -0.9414, -0.9414],
#            [-0.8164, -0.8164, -0.8164,  ..., -0.9258, -0.9336, -0.9336],
#            [-0.8164, -0.8164, -0.8164,  ..., -0.9258, -0.9258, -0.9336]]]]),
#  tensor([2, 2, 0, 2, 2, 2, 0, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2,
#          2, 2, 2, 2, 1, 1, 2, 2])]

# %% [markdown]
# # Define Inception Resnet V1 module

# %%
resnet = InceptionResnetV1(
    classify=True,
    pretrained='vggface2',
    num_classes=3
).to(device)

# %% [markdown]
# # Define optimizer, scheduler, loss, evaluation functions

# %%
optimizer = torch.optim.AdamW(resnet.parameters(), lr=0.001)
scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, [5, 10])

loss_fn = torch.nn.CrossEntropyLoss()
metrics = {
    'fps': training.BatchTimer(),
    'acc': training.accuracy
}

# %% [markdown]
# # Train model

# %%
writer = SummaryWriter()
writer.iteration, writer.interval = 0, 10

print('\n\nInitial')
print('-' * 10)
resnet.eval()
training.pass_epoch(
    resnet, loss_fn, valid_loader,
    batch_metrics=metrics, show_running=True, device=device,
    writer=writer
)

for epoch in range(epochs):
    print('\nEpoch {}/{}'.format(epoch + 1, epochs))
    print('-' * 10)

    resnet.train()
    training.pass_epoch(
        resnet, loss_fn, train_loader, optimizer, scheduler,
        batch_metrics=metrics, show_running=True, device=device,
        writer=writer
    )

    resnet.eval()
    training.pass_epoch(
        resnet, loss_fn, valid_loader,
        batch_metrics=metrics, show_running=True, device=device,
        writer=writer
    )

writer.close()
# Out:
# Initial
# ----------
# Valid |     2/8    | loss:    1.2173 | fps:  329.4587 | acc:    0.3125
# C:\Users\zhouy\AppData\Local\Temp/ipykernel_20240/2642461197.py:15: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   return self.transform(self.x[index]),torch.tensor(self.y[index],dtype=torch.long)
# Valid |     8/8    | loss:    1.2080 | fps:  396.4773 | acc:    0.2891
#
# Epoch 1/16
# ----------
# Train |    70/70   | loss:    1.0089 | fps:  134.2928 | acc:    0.6504
# Valid |     8/8    | loss:    0.6693 | fps:  581.0668 | acc:    0.8516
#
# Epoch 2/16
# ----------
# Train |    70/70   | loss:    0.6908 | fps:  135.4736 | acc:    0.7823
# Valid |     8/8    | loss:    0.5264 | fps:  562.1762 | acc:    0.8555
#
# Epoch 3/16
# ----------
# Train |    70/70   | loss:    0.6704 | fps:  137.0727 | acc:    0.7857
# Valid |     8/8    | loss:    0.4974 | fps:  569.3310 | acc:    0.8555
#
# Epoch 4/16
# ----------
# Train |    70/70   | loss:    0.6926 | fps:  137.9244 | acc:    0.7834
# Valid |     8/8    | loss:    0.8425 | fps:  575.3994 | acc:    0.8464
#
# Epoch 5/16
# ----------
# Train |    70/70   | loss:    0.6649 | fps:  136.8328 | acc:    0.7868
# Valid |     8/8    | loss:    0.4992 | fps:  588.2426 | acc:    0.8529
#
# Epoch 6/16
# ----------
# Train |    70/70   | loss:    0.6466 | fps:  131.6784 | acc:    0.7875
# Valid |     8/8    | loss:    0.4998 | fps:  589.4493 | acc:    0.8529
#
# Epoch 7/16
# ----------
# Train |    70/70   | loss:    0.6412 | fps:  138.3128 | acc:    0.7886
# Valid |     8/8    | loss:    0.5036 | fps:  582.6628 | acc:    0.8555
#
# Epoch 8/16
# ----------
# Train |    70/70   | loss:    0.6351 | fps:  130.1318 | acc:    0.7890
# Valid |     8/8    | loss:    0.5447 | fps:  571.9622 | acc:    0.8490
#
# Epoch 9/16
# ----------
# Train |    70/70   | loss:    0.6301 | fps:  129.4445 | acc:    0.7868
# Valid |     8/8    | loss:    0.5004 | fps:  571.0718 | acc:    0.8581
#
# Epoch 10/16
# ----------
# Train |    70/70   | loss:    0.6319 | fps:  138.9297 | acc:    0.7899
# Valid |     8/8    | loss:    0.5126 | fps:  572.2302 | acc:    0.8542
#
# Epoch 11/16
# ----------
# Train |    70/70   | loss:    0.6248 | fps:  137.8548 | acc:    0.7888
# Valid |     8/8    | loss:    0.5549 | fps:  570.9882 | acc:    0.8568
#
# Epoch 12/16
# ----------
# Train |    70/70   | loss:    0.6254 | fps:  137.8313 | acc:    0.7908
# Valid |     8/8    | loss:    0.4891 | fps:  572.6775 | acc:    0.8594
#
# Epoch 13/16
# ----------
# Train |    70/70   | loss:    0.6254 | fps:  136.9527 | acc:    0.7868
# Valid |     8/8    | loss:    0.5254 | fps:  564.2677 | acc:    0.8568
#
# Epoch 14/16
# ----------
# Train |    70/70   | loss:    0.6224 | fps:  135.8427 | acc:    0.7890
# Valid |     8/8    | loss:    0.5718 | fps:  576.8841 | acc:    0.8568
#
# Epoch 15/16
# ----------
# Train |    70/70   | loss:    0.6225 | fps:  135.5723 | acc:    0.7910
# Valid |     8/8    | loss:    0.5778 | fps:  573.7977 | acc:    0.8542
#
# Epoch 16/16
# ----------
# Train |    70/70   | loss:    0.6230 | fps:  132.2900 | acc:    0.7868
# Valid |     8/8    | loss:    0.5103 | fps:  489.9124 | acc:    0.8620

# %%
torch.save(resnet.state_dict(),'dataset1_pic_race_model.pt')
